# %% [markdown]
# ## Comcast Data Analysis

# %%
#import required librarires
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#import Comcast dataset csv file in Dataframe
comcast_df = pd.read_csv('C:/Users/hleka/Google Drive/Data Science/Simplilearn/Python/Graded_Project/Comcast/Comcast_telecom_complaints_data.csv', parse_dates=['Date'])

# %%
#preview the camcast data
comcast_df.head()
# Out:
#   Ticket #                                 Customer Complaint       Date  \
# 0   250635                      Comcast Cable Internet Speeds 2015-04-22
# 1   223441       Payment disappear - service got disconnected 2015-04-08
# 2   242732                                  Speed and Service 2015-04-18
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4   307175         Comcast not working and no service to boot 2015-05-26
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# 1     30102  Closed                          No
# 2     30101  Closed                         Yes
# 3     30101    Open                         Yes
# 4     30101  Solved                          No

# %%
# checking column data types
print(comcast_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   datetime64[ns]
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 191.2+ KB
# None

# %%
# extract month and day into new coulmns
comcast_df['year'] = comcast_df['Date'].dt.year
comcast_df['month'] = comcast_df['Date'].dt.month
comcast_df['day'] = comcast_df['Date'].dt.day
comcast_df.head()
# Out:
#   Ticket #                                 Customer Complaint       Date  \
# 0   250635                      Comcast Cable Internet Speeds 2015-04-22
# 1   223441       Payment disappear - service got disconnected 2015-04-08
# 2   242732                                  Speed and Service 2015-04-18
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4   307175         Comcast not working and no service to boot 2015-05-26
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone  year  month  day
# 0     21009  Closed                          No  2015      4   22
# 1     30102  Closed                          No  2015      4    8
# 2     30101  Closed                         Yes  2015      4   18
# 3     30101    Open                         Yes  2015      5    7
# 4     30101  Solved                          No  2015      5   26

# %%
comcast_df['year'].unique()
# Out:
# array([2015], dtype=int64)

# %%
# Monthly trends of number of complaints  
sns.countplot(x=comcast_df['month'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
# Daily trends of number of complaints  
sns.countplot(x=comcast_df['day'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
# Frequency of complain types
comcast_df['Customer Complaint'].value_counts()
# Out:
# Comcast                                          83
# Comcast Internet                                 18
# Comcast Data Cap                                 17
# comcast                                          13
# Comcast Billing                                  11
#                                                  ..
# Improper Billing and non resolution of issues     1
# Deceptive trade                                   1
# intermittent internet                             1
# Internet Speed on Wireless Connection             1
# Comcast, Ypsilanti MI Internet Speed              1
# Name: Customer Complaint, Length: 1841, dtype: int64

# %%
# Complaints with the highest frequency
comcast_df['Customer Complaint'].value_counts().index[0]
# Out:
# 'Comcast'

# %%
comcast_df[comcast_df['Customer Complaint'] == 'Comcast']
# Out:
#      Ticket # Customer Complaint       Date Date_month_year         Time  \
# 35     354116            Comcast 2015-06-20       20-Jun-15   5:03:09 PM
# 37     373874            Comcast 2015-06-30       30-Jun-15  12:24:57 AM
# 47     309379            Comcast 2015-05-27       27-May-15   1:50:37 PM
# 61     352100            Comcast 2015-06-19       19-Jun-15   2:36:57 PM
# 91     307799            Comcast 2015-05-26       26-May-15   4:29:57 PM
# ...       ...                ...        ...             ...          ...
# 2168   284195            Comcast 2015-05-11       05-Nov-15   5:25:20 PM
# 2170   359831            Comcast 2015-06-23       23-Jun-15   7:09:28 PM
# 2180   247649            Comcast 2015-04-21       21-Apr-15   2:04:59 PM
# 2189   360139            Comcast 2015-06-23       23-Jun-15   8:48:09 PM
# 2211   221763            Comcast 2015-04-07       04-Jul-15   1:49:52 PM
#
#             Received Via         City          State  Zip code  Status  \
# 35              Internet   Alpharetta        Georgia     30022  Solved
# 37    Customer Care Call        Alvin          Texas     77511  Solved
# 47              Internet    Ann Arbor       Michigan     48105  Solved
# 61              Internet    Arlington       Virginia     22206    Open
# 91    Customer Care Call      Atlanta        Georgia     30318  Solved
# ...                  ...          ...            ...       ...     ...
# 2168            Internet    Westfield  Massachusetts      1085    Open
# 2170  Customer Care Call  Westminster       Maryland     21158    Open
# 2180            Internet   Wilmington       Delaware     19805  Closed
# 2189  Customer Care Call      Windsor       Colorado     80550  Solved
# 2211            Internet      Wyoming       Michigan     49509  Closed
#
#      Filing on Behalf of Someone  year  month  day
# 35                            No  2015      6   20
# 37                            No  2015      6   30
# 47                            No  2015      5   27
# 61                            No  2015      6   19
# 91                            No  2015      5   26
# ...                          ...   ...    ...  ...
# 2168                          No  2015      5   11
# 2170                          No  2015      6   23
# 2180                         Yes  2015      4   21
# 2189                          No  2015      6   23
# 2211                          No  2015      4    7
#
# [83 rows x 14 columns]

# %%
# Complaints with the lowest frequency
comcast_df['Customer Complaint'].value_counts().index[-1]
# Out:
# 'Comcast, Ypsilanti MI Internet Speed'

# %%
comcast_df[comcast_df['Customer Complaint'] == 'Comcast, Ypsilanti MI Internet Speed']
# Out:
#      Ticket #                    Customer Complaint       Date  \
# 2223   363614  Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
#      Date_month_year         Time        Received Via       City     State  \
# 2223       24-Jun-15  10:28:33 PM  Customer Care Call  Ypsilanti  Michigan
#
#       Zip code Status Filing on Behalf of Someone  year  month  day
# 2223     48198   Open                         Yes  2015      6   24

# %%
# Create a new categorical variable with value as Open and Closed
#create a list of conditions
conditions = [
    (comcast_df['Status'] == 'Open'),
    (comcast_df['Status'] == 'Pending'),
    (comcast_df['Status'] == 'Closed'),
    (comcast_df['Status'] == 'Solved'),
]

# create a list of values we want to assign to each condition
values = ['Open', 'Open', 'Closed', 'Closed']

#create a new column and use np.select to assign values to using our list arguements
comcast_df['status_summary'] = np.select(conditions, values)

# %%
# del comcast_df['status_summary']

# %%
comcast_df.head()
# Out:
#   Ticket #                                 Customer Complaint       Date  \
# 0   250635                      Comcast Cable Internet Speeds 2015-04-22
# 1   223441       Payment disappear - service got disconnected 2015-04-08
# 2   242732                                  Speed and Service 2015-04-18
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4   307175         Comcast not working and no service to boot 2015-05-26
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone  year  month  day  \
# 0     21009  Closed                          No  2015      4   22
# 1     30102  Closed                          No  2015      4    8
# 2     30101  Closed                         Yes  2015      4   18
# 3     30101    Open                         Yes  2015      5    7
# 4     30101  Solved                          No  2015      5   26
#
#   status_summary
# 0         Closed
# 1         Closed
# 2         Closed
# 3           Open
# 4         Closed

# %%
comcast_df.tail()
# Out:
#      Ticket #                          Customer Complaint       Date  \
# 2219   213550                        Service Availability 2015-04-02
# 2220   318775  Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                     complaint about comcast 2015-06-09
# 2222   360489      Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614        Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
#      Date_month_year         Time        Received Via        City     State  \
# 2219       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2220       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2221       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2222       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
# 2223       24-Jun-15  10:28:33 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone  year  month  day  \
# 2219     32466  Closed                          No  2015      4    2
# 2220     48197  Solved                          No  2015      6    2
# 2221     48197  Solved                          No  2015      6    9
# 2222     48197  Solved                          No  2015      6   23
# 2223     48198    Open                         Yes  2015      6   24
#
#      status_summary
# 2219         Closed
# 2220         Closed
# 2221         Closed
# 2222         Closed
# 2223           Open

# %%
#comcast_df.groupby(['State'])['Customer Complaint'].value_counts().max()
# comcast_df.groupby(['State']).groups
#comcast_df.groupby(['State','Customer Complaint']).groups

# %%
#grouped = comcast_df.groupby('State')
#grouped = comcast_df.groupby(['State','Customer Complaint']).groups
#for name,group in grouped:
   #print (name)
   #print (group)

# %%
 # sns.countplot(comcast_df.groupby(['State'])['Customer Complaint'].value_counts())

# %%
grouped = comcast_df.groupby('State')
chart = grouped['Customer Complaint'].size()
print(chart)
# Out:
# State
# Alabama                  26
# Arizona                  20
# Arkansas                  6
# California              220
# Colorado                 80
# Connecticut              12
# Delaware                 12
# District Of Columbia     16
# District of Columbia      1
# Florida                 240
# Georgia                 288
# Illinois                164
# Indiana                  59
# Iowa                      1
# Kansas                    2
# Kentucky                  7
# Louisiana                13
# Maine                     5
# Maryland                 78
# Massachusetts            61
# Michigan                115
# Minnesota                33
# Mississippi              39
# Missouri                  4
# Montana                   1
# Nevada                    1
# New Hampshire            12
# New Jersey               75
# New Mexico               15
# New York                  6
# North Carolina            3
# Ohio                      3
# Oregon                   49
# Pennsylvania            130
# Rhode Island              1
# South Carolina           18
# Tennessee               143
# Texas                    71
# Utah                     22
# Vermont                   3
# Virginia                 60
# Washington               98
# West Virginia            11
# Name: Customer Complaint, dtype: int64

# %%
df = pd.DataFrame(data=chart)
df.sort_values(by=['Customer Complaint'], inplace=True, ascending=False)
df.head()
# Out:
#             Customer Complaint
# State
# Georgia                    288
# Florida                    240
# California                 220
# Illinois                   164
# Tennessee                  143

# %%
# state with the maximum complaints
Georgia

# %%
comcast_df.groupby(['status_summary', 'State']).max()
# Out:
#                              Ticket #  \
# status_summary State
# Closed         Alabama         363900
#                Arizona         368168
#                Arkansas        362556
#                California      375439
#                Colorado        370930
# ...                               ...
# Open           Utah            370691
#                Vermont         339548
#                Virginia        370538
#                Washington      375809
#                West Virginia   373879
#
#                                                              Customer Complaint  \
# status_summary State
# Closed         Alabama                                        monthly data caps
#                Arizona        comcast is changing my paper bill to ecobill w...
#                Arkansas                                        xfinity Internet
#                California     unfair pricing and raising of pricing and char...
#                Colorado                        no warning before price increase
# ...                                                                         ...
# Open           Utah                                            Speed Throttling
#                Vermont                                      Internet Throttling
#                Virginia              without service despite willingness to pay
#                Washington                  tInternet Service Provider Complaint
#                West Virginia  Service refusal and lower than advertised speeds.
#
#                                    Date Date_month_year        Time  \
# status_summary State
# Closed         Alabama       2015-06-25       25-Jun-15  9:50:19 AM
#                Arizona       2015-06-26       29-May-15  9:52:27 PM
#                Arkansas      2015-06-24       24-Jun-15  7:27:25 PM
#                California    2015-06-30       30-Jun-15  9:59:29 PM
#                Colorado      2015-06-28       31-May-15  9:33:54 PM
# ...                                 ...             ...         ...
# Open           Utah          2015-06-28       30-May-15  9:21:41 PM
#                Vermont       2015-06-13       13-Jun-15  9:21:20 PM
#                Virginia      2015-06-27       30-May-15  9:49:33 AM
#                Washington    2015-06-30       31-May-15  9:28:16 AM
#                West Virginia 2015-06-30       30-Jun-15  8:16:57 PM
#
#                              Received Via                City  Zip code  \
# status_summary State
# Closed         Alabama           Internet           Tuscumbia     36609
#                Arizona           Internet              Tucson     85749
#                Arkansas          Internet   North Little Rock     72223
#                California        Internet             Windsor     95966
#                Colorado          Internet             Windsor     81623
# ...                                   ...                 ...       ...
# Open           Utah              Internet  Washington Terrace     84405
#                Vermont           Internet        Saint Albans      5478
#                Virginia          Internet          Woodbridge     23831
#                Washington        Internet              Vashon     99212
#                West Virginia     Internet          Morgantown     26508
#
#                                Status Filing on Behalf of Someone  year  \
# status_summary State
# Closed         Alabama         Solved                         Yes  2015
#                Arizona         Solved                         Yes  2015
#                Arkansas        Solved                          No  2015
#                California      Solved                         Yes  2015
#                Colorado        Solved                         Yes  2015
# ...                               ...                         ...   ...
# Open           Utah              Open                          No  2015
#                Vermont           Open                          No  2015
#                Virginia       Pending                          No  2015
#                Washington     Pending                         Yes  2015
#                West Virginia     Open                          No  2015
#
#                               month  day
# status_summary State
# Closed         Alabama            6   25
#                Arizona            6   29
#                Arkansas           6   24
#                California         6   30
#                Colorado           6   31
# ...                             ...  ...
# Open           Utah               6   30
#                Vermont            6   13
#                Virginia           6   30
#                Washington         6   31
#                West Virginia      6   30
#
# [77 rows x 13 columns]

# %%
# resolved complaints received through the Internet
len(comcast_df[(comcast_df['status_summary'] =='Closed') & (comcast_df['Received Via'] == 'Internet')])
# Out:
# 843

# %%
# resolved complaints received through customer care calls
len(comcast_df[(comcast_df['status_summary'] =='Closed') & (comcast_df['Received Via'] == 'Customer Care Call')])
# Out:
# 864

# %%
# percentage of complaints resolved received through the Internet and customer care calls
(comcast_df['status_summary'].value_counts(normalize=True)) *100
# Out:
# Closed    76.753597
# Open      23.246403
# Name: status_summary, dtype: float64
